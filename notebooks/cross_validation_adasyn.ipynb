# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import sys
import os
sys.path.append(os.path.abspath('../modules'))
from best_pipelines import models_to_cv
from cross_validation import cross_validation
from preproc import PhishingDatasetPreproc
from imblearn.over_sampling import ADASYN

# %% [markdown]
# ## Setup

# %%
np.random.seed(42)

# %%
prep = PhishingDatasetPreproc()
dataset, X, y = prep.basic_operations()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

adasyn = ADASYN(sampling_strategy='auto', random_state=42)
X_train_adasyn, y_train_adasyn = adasyn.fit_resample(X_train, y_train)

# %%
best_pipelines, ensembles = models_to_cv()

# %%
cv = cross_validation(X_train_adasyn, y_train_adasyn, best_pipelines)
# Out:
# Model KNN
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5
# Fold: 6
# Fold: 7
# Fold: 8
# Fold: 9
#
#  Metrics:
#   model_name    fold      ACSA    recall                      CM  f1_score  \
# 0        KNN  fold_0  0.974373  0.973799  [[467, 12], [12, 446]]  0.973799
# 1        KNN  fold_1  0.970859  0.956332   [[472, 7], [20, 438]]  0.970100
# 2        KNN  fold_2  0.962221  0.943231   [[470, 9], [26, 432]]  0.961068
# 3        KNN  fold_3  0.963361  0.947598  [[469, 10], [24, 434]]  0.962306
# 4        KNN  fold_4  0.956906  0.938865  [[467, 12], [28, 430]]  0.955556
# 5        KNN  fold_5  0.975369  0.971616  [[469, 10], [13, 445]]  0.974808
# 6        KNN  fold_6  0.966686  0.958425  [[467, 12], [19, 438]]  0.965821
# 7        KNN  fold_7  0.965441  0.949672   [[470, 9], [23, 434]]  0.964444
# 8        KNN  fold_8  0.973251  0.971554  [[467, 12], [13, 444]]  0.972618
# 9        KNN  fold_9  0.966385  0.945295   [[473, 6], [25, 432]]  0.965363
#
#    training_time  inference_time  error_rate  train_accuracy  test_accuracy  \
# 0       0.095838        0.125072    0.025614        0.986950       0.974386
# 1       0.091738        0.116692    0.028815        0.986357       0.971185
# 2       0.083338        0.125208    0.037353        0.988255       0.962647
# 3       0.099914        0.142494    0.036286        0.987899       0.963714
# 4       0.097628        0.134726    0.042689        0.987662       0.957311
# 5       0.091944        0.117000    0.024546        0.987306       0.975454
# 6       0.083600        0.123910    0.033120        0.988019       0.966880
# 7       0.099664        0.124725    0.034188        0.988256       0.965812
# 8       0.083398        0.116740    0.026709        0.986002       0.973291
# 9       0.091172        0.125154    0.033120        0.987900       0.966880
#
#    precision
# 0   0.973799
# 1   0.984270
# 2   0.979592
# 3   0.977477
# 4   0.972851
# 5   0.978022
# 6   0.973333
# 7   0.979684
# 8   0.973684
# 9   0.986301
# Model LVQ
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5
# Fold: 6
# Fold: 7
# Fold: 8
# Fold: 9
#
#  Metrics:
#   model_name    fold      ACSA    recall                       CM  f1_score  \
# 0        LVQ  fold_0  0.850915  0.722707  [[469, 10], [127, 331]]  0.828536
# 1        LVQ  fold_1  0.833400  0.685590   [[470, 9], [144, 314]]  0.804097
# 2        LVQ  fold_2  0.832835  0.707424  [[459, 20], [134, 324]]  0.807980
# 3        LVQ  fold_3  0.879682  0.796943   [[461, 18], [93, 365]]  0.868014
# 4        LVQ  fold_4  0.838533  0.729258  [[454, 25], [124, 334]]  0.817625
# 5        LVQ  fold_5  0.853099  0.727074  [[469, 10], [125, 333]]  0.831461
# 6        LVQ  fold_6  0.841960  0.708972  [[467, 12], [133, 324]]  0.817150
# 7        LVQ  fold_7  0.844399  0.724289  [[462, 17], [126, 331]]  0.822360
# 8        LVQ  fold_8  0.861402  0.737418   [[472, 7], [120, 337]]  0.841448
# 9        LVQ  fold_9  0.850875  0.778993  [[442, 37], [101, 356]]  0.837647
#
#    training_time  inference_time  error_rate  train_accuracy  test_accuracy  \
# 0       9.346689        0.049010    0.146211        0.846364       0.853789
# 1       9.118781        0.046527    0.163287        0.848618       0.836713
# 2       9.351475        0.029804    0.164354        0.857397       0.835646
# 3       9.447610        0.041696    0.118463        0.874481       0.881537
# 4       9.040206        0.052840    0.159018        0.857990       0.840982
# 5      16.480771        0.125641    0.144077        0.841855       0.855923
# 6      23.672958        0.049728    0.154915        0.854330       0.845085
# 7       9.296109        0.039128    0.152778        0.860142       0.847222
# 8       9.414041        0.048986    0.135684        0.848636       0.864316
# 9      17.445080        0.172743    0.147436        0.864176       0.852564
#
#    precision
# 0   0.970674
# 1   0.972136
# 2   0.941860
# 3   0.953003
# 4   0.930362
# 5   0.970845
# 6   0.964286
# 7   0.951149
# 8   0.979651
# 9   0.905852
# Model DTR
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5
# Fold: 6
# Fold: 7
# Fold: 8
# Fold: 9
#
#  Metrics:
#   model_name    fold      ACSA    recall                      CM  f1_score  \
# 0        DTR  fold_0  0.935225  0.949782  [[441, 38], [23, 435]]  0.934479
# 1        DTR  fold_1  0.927535  0.932314  [[442, 37], [31, 427]]  0.926247
# 2        DTR  fold_2  0.915478  0.906114  [[443, 36], [43, 415]]  0.913091
# 3        DTR  fold_3  0.934133  0.947598  [[441, 38], [24, 434]]  0.933333
# 4        DTR  fold_4  0.913726  0.921397  [[434, 45], [36, 422]]  0.912432
# 5        DTR  fold_5  0.915814  0.921397  [[436, 43], [36, 422]]  0.914410
# 6        DTR  fold_6  0.927562  0.936543  [[440, 39], [29, 428]]  0.926407
# 7        DTR  fold_7  0.924028  0.919037  [[445, 34], [37, 420]]  0.922064
# 8        DTR  fold_8  0.929900  0.947484  [[437, 42], [24, 433]]  0.929185
# 9        DTR  fold_9  0.933183  0.954048  [[437, 42], [21, 436]]  0.932620
#
#    training_time  inference_time  error_rate  train_accuracy  test_accuracy  \
# 0       0.631672        0.021737    0.065101        0.927156       0.934899
# 1       0.591513        0.016737    0.072572        0.928224       0.927428
# 2       0.623463        0.012084    0.084312        0.928936       0.915688
# 3       0.604621        0.024990    0.066169        0.926919       0.933831
# 4       0.660887        0.025824    0.086446        0.928461       0.913554
# 5       0.549037        0.047528    0.084312        0.929292       0.915688
# 6       0.588586        0.016575    0.072650        0.926690       0.927350
# 7       0.658940        0.031245    0.075855        0.927639       0.924145
# 8       0.629348        0.015642    0.070513        0.926572       0.929487
# 9       0.534471        0.016172    0.067308        0.927402       0.932692
#
#    precision
# 0   0.919662
# 1   0.920259
# 2   0.920177
# 3   0.919492
# 4   0.903640
# 5   0.907527
# 6   0.916488
# 7   0.925110
# 8   0.911579
# 9   0.912134
# Model SVM
# Fold: 0
# c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Fold: 1
# c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Fold: 2
# c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Fold: 3
# c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Fold: 4
# c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Fold: 5
# c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Fold: 6
# c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Fold: 7
# c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Fold: 8
# c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Fold: 9
# c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#  Metrics:
#   model_name    fold      ACSA    recall                      CM  f1_score  \
# 0        SVM  fold_0  0.954962  0.945415  [[462, 17], [25, 433]]  0.953744
# 1        SVM  fold_1  0.948651  0.943231  [[457, 22], [26, 432]]  0.947368
# 2        SVM  fold_2  0.939870  0.923581  [[458, 21], [35, 423]]  0.937916
# 3        SVM  fold_3  0.953066  0.954148  [[456, 23], [21, 437]]  0.952070
# 4        SVM  fold_4  0.944380  0.938865  [[455, 24], [28, 430]]  0.942982
# 5        SVM  fold_5  0.954301  0.962882  [[453, 26], [17, 441]]  0.953514
# 6        SVM  fold_6  0.949633  0.943107  [[458, 21], [26, 431]]  0.948295
# 7        SVM  fold_7  0.945407  0.940919  [[455, 24], [27, 430]]  0.944018
# 8        SVM  fold_8  0.952965  0.951860  [[457, 22], [22, 435]]  0.951860
# 9        SVM  fold_9  0.959430  0.960613  [[459, 20], [18, 439]]  0.958515
#
#    training_time  inference_time  error_rate  train_accuracy  test_accuracy  \
# 0       6.008660        0.131830    0.044824        0.960256       0.955176
# 1       5.666991        0.141254    0.051227        0.955511       0.948773
# 2       5.953210        0.141334    0.059765        0.959307       0.940235
# 3       5.648706        0.192827    0.046958        0.960968       0.953042
# 4       5.966589        0.157007    0.055496        0.959307       0.944504
# 5       6.400100        0.157001    0.045891        0.958477       0.954109
# 6       2.759889        0.063174    0.050214        0.961447       0.949786
# 7       2.460867        0.066282    0.054487        0.959549       0.945513
# 8       2.436315        0.123693    0.047009        0.961091       0.952991
# 9       5.695926        0.126203    0.040598        0.962515       0.959402
#
#    precision
# 0   0.962222
# 1   0.951542
# 2   0.952703
# 3   0.950000
# 4   0.947137
# 5   0.944325
# 6   0.953540
# 7   0.947137
# 8   0.951860
# 9   0.956427
# Model RF
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5
# Fold: 6
# Fold: 7
# Fold: 8
# Fold: 9
#
#  Metrics:
#   model_name    fold      ACSA    recall                      CM  f1_score  \
# 0         RF  fold_0  0.975274  0.967249   [[471, 8], [15, 443]]  0.974697
# 1         RF  fold_1  0.967728  0.956332  [[469, 10], [20, 438]]  0.966887
# 2         RF  fold_2  0.955862  0.938865  [[466, 13], [28, 430]]  0.954495
# 3         RF  fold_3  0.962556  0.958515  [[463, 16], [19, 439]]  0.961665
# 4         RF  fold_4  0.963361  0.947598  [[469, 10], [24, 434]]  0.962306
# 5         RF  fold_5  0.969011  0.967249  [[465, 14], [15, 443]]  0.968306
# 6         RF  fold_6  0.965542  0.954048  [[468, 11], [21, 436]]  0.964602
# 7         RF  fold_7  0.966636  0.956236  [[468, 11], [20, 437]]  0.965746
# 8         RF  fold_8  0.972157  0.969365  [[467, 12], [14, 443]]  0.971491
# 9         RF  fold_9  0.973150  0.967177  [[469, 10], [15, 442]]  0.972497
#
#    training_time  inference_time  error_rate  train_accuracy  test_accuracy  \
# 0       3.003678        0.267598    0.024546        0.977340       0.975454
# 1       2.722198        0.079105    0.032017        0.977696       0.967983
# 2       3.269843        0.063142    0.043757        0.978764       0.956243
# 3       2.696659        0.046193    0.037353        0.978764       0.962647
# 4       1.467664        0.047520    0.036286        0.979001       0.963714
# 5       1.488142        0.031252    0.030950        0.977577       0.969050
# 6       1.451025        0.029603    0.034188        0.978173       0.965812
# 7       1.459228        0.033349    0.033120        0.978410       0.966880
# 8       1.466459        0.041480    0.027778        0.977817       0.972222
# 9       1.463368        0.031219    0.026709        0.977699       0.973291
#
#    precision
# 0   0.982262
# 1   0.977679
# 2   0.970655
# 3   0.964835
# 4   0.977477
# 5   0.969365
# 6   0.975391
# 7   0.975446
# 8   0.973626
# 9   0.977876
# Model XGB
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5
# Fold: 6
# Fold: 7
# Fold: 8
# Fold: 9
#
#  Metrics:
#   model_name    fold      ACSA    recall                      CM  f1_score  \
# 0        XGB  fold_0  0.979641  0.975983   [[471, 8], [11, 447]]  0.979189
# 1        XGB  fold_1  0.972046  0.962882   [[470, 9], [17, 441]]  0.971366
# 2        XGB  fold_2  0.965640  0.956332  [[467, 12], [20, 438]]  0.964758
# 3        XGB  fold_3  0.972094  0.965066  [[469, 10], [16, 442]]  0.971429
# 4        XGB  fold_4  0.969911  0.960699  [[469, 10], [18, 440]]  0.969163
# 5        XGB  fold_5  0.974373  0.973799  [[467, 12], [12, 446]]  0.973799
# 6        XGB  fold_6  0.965743  0.962801  [[464, 15], [17, 440]]  0.964912
# 7        XGB  fold_7  0.969918  0.962801  [[468, 11], [17, 440]]  0.969163
# 8        XGB  fold_8  0.971956  0.960613   [[471, 8], [18, 439]]  0.971239
# 9        XGB  fold_9  0.973301  0.973742  [[466, 13], [12, 445]]  0.972678
#
#    training_time  inference_time  error_rate  train_accuracy  test_accuracy  \
# 0       1.624599        0.008340    0.020277        0.986238       0.979723
# 1       1.591307        0.005064    0.027748        0.986357       0.972252
# 2       1.615566        0.008285    0.034152        0.986713       0.965848
# 3       1.616546        0.005695    0.027748        0.987187       0.972252
# 4       1.649478        0.000000    0.029883        0.986238       0.970117
# 5       1.579654        0.001460    0.025614        0.985763       0.974386
# 6       1.583726        0.012322    0.034188        0.986240       0.965812
# 7       1.600367        0.008376    0.029915        0.986121       0.970085
# 8       1.617067        0.000000    0.027778        0.984698       0.972222
# 9       1.649334        0.000000    0.026709        0.985884       0.973291
#
#    precision
# 0   0.982418
# 1   0.980000
# 2   0.973333
# 3   0.977876
# 4   0.977778
# 5   0.973799
# 6   0.967033
# 7   0.975610
# 8   0.982103
# 9   0.971616
# Model LGBM
# Fold: 0
# c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py:150: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] O sistema não pode encontrar o arquivo especificado
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 227, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\giull\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [LightGBM] [Info] Number of positive: 4118, number of negative: 4311
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001185 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 89
# [LightGBM] [Info] Number of data points in the train set: 8429, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.488551 -> initscore=-0.045802
# [LightGBM] [Info] Start training from score -0.045802
# Fold: 1
# [LightGBM] [Info] Number of positive: 4118, number of negative: 4311
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000554 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 89
# [LightGBM] [Info] Number of data points in the train set: 8429, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.488551 -> initscore=-0.045802
# [LightGBM] [Info] Start training from score -0.045802
# Fold: 2
# [LightGBM] [Info] Number of positive: 4118, number of negative: 4311
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000671 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 89
# [LightGBM] [Info] Number of data points in the train set: 8429, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.488551 -> initscore=-0.045802
# [LightGBM] [Info] Start training from score -0.045802
# Fold: 3
# [LightGBM] [Info] Number of positive: 4118, number of negative: 4311
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000757 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 89
# [LightGBM] [Info] Number of data points in the train set: 8429, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.488551 -> initscore=-0.045802
# [LightGBM] [Info] Start training from score -0.045802
# Fold: 4
# [LightGBM] [Info] Number of positive: 4118, number of negative: 4311
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000530 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 89
# [LightGBM] [Info] Number of data points in the train set: 8429, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.488551 -> initscore=-0.045802
# [LightGBM] [Info] Start training from score -0.045802
# Fold: 5
# [LightGBM] [Info] Number of positive: 4118, number of negative: 4311
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000642 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 89
# [LightGBM] [Info] Number of data points in the train set: 8429, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.488551 -> initscore=-0.045802
# [LightGBM] [Info] Start training from score -0.045802
# Fold: 6
# [LightGBM] [Info] Number of positive: 4119, number of negative: 4311
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000570 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 89
# [LightGBM] [Info] Number of data points in the train set: 8430, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.488612 -> initscore=-0.045559
# [LightGBM] [Info] Start training from score -0.045559
# Fold: 7
# [LightGBM] [Info] Number of positive: 4119, number of negative: 4311
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000618 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 89
# [LightGBM] [Info] Number of data points in the train set: 8430, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.488612 -> initscore=-0.045559
# [LightGBM] [Info] Start training from score -0.045559
# Fold: 8
# [LightGBM] [Info] Number of positive: 4119, number of negative: 4311
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000591 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 89
# [LightGBM] [Info] Number of data points in the train set: 8430, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.488612 -> initscore=-0.045559
# [LightGBM] [Info] Start training from score -0.045559
# Fold: 9
# [LightGBM] [Info] Number of positive: 4119, number of negative: 4311
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000428 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 89
# [LightGBM] [Info] Number of data points in the train set: 8430, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.488612 -> initscore=-0.045559
# [LightGBM] [Info] Start training from score -0.045559
#
#  Metrics:
#   model_name    fold      ACSA    recall                      CM  f1_score  \
# 0       LGBM  fold_0  0.981728  0.975983   [[473, 6], [11, 447]]  0.981339
# 1       LGBM  fold_1  0.971999  0.960699   [[471, 8], [18, 440]]  0.971302
# 2       LGBM  fold_2  0.965688  0.958515  [[466, 13], [19, 439]]  0.964835
# 3       LGBM  fold_3  0.973186  0.967249  [[469, 10], [15, 443]]  0.972558
# 4       LGBM  fold_4  0.970007  0.965066  [[467, 12], [16, 442]]  0.969298
# 5       LGBM  fold_5  0.974373  0.973799  [[467, 12], [12, 446]]  0.973799
# 6       LGBM  fold_6  0.960272  0.951860  [[464, 15], [22, 435]]  0.959206
# 7       LGBM  fold_7  0.974244  0.969365  [[469, 10], [14, 443]]  0.973626
# 8       LGBM  fold_8  0.974244  0.969365  [[469, 10], [14, 443]]  0.973626
# 9       LGBM  fold_9  0.975389  0.973742  [[468, 11], [12, 445]]  0.974808
#
#    training_time  inference_time  error_rate  train_accuracy  test_accuracy  \
# 0       0.778112        0.002001    0.018143        0.986475       0.981857
# 1       0.754884        0.015627    0.027748        0.987543       0.972252
# 2       0.788517        0.002722    0.034152        0.987306       0.965848
# 3       0.869153        0.013005    0.026681        0.988136       0.973319
# 4       1.011914        0.000000    0.029883        0.987306       0.970117
# 5       0.903810        0.000000    0.025614        0.986475       0.974386
# 6       0.764000        0.000000    0.039530        0.986833       0.960470
# 7       0.731363        0.000000    0.025641        0.987189       0.974359
# 8       0.782585        0.000000    0.025641        0.985884       0.974359
# 9       0.747109        0.000000    0.024573        0.987070       0.975427
#
#    precision
# 0   0.986755
# 1   0.982143
# 2   0.971239
# 3   0.977925
# 4   0.973568
# 5   0.973799
# 6   0.966667
# 7   0.977925
# 8   0.977925
# 9   0.975877
# Model MLP
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5
# Fold: 6
# Fold: 7
# Fold: 8
# Fold: 9
#
#  Metrics:
#   model_name    fold      ACSA    recall                      CM  f1_score  \
# 0        MLP  fold_0  0.976318  0.967249   [[472, 7], [15, 443]]  0.975771
# 1        MLP  fold_1  0.973090  0.962882   [[471, 8], [17, 441]]  0.972437
# 2        MLP  fold_2  0.960325  0.951965  [[464, 15], [22, 436]]  0.959296
# 3        MLP  fold_3  0.969911  0.960699  [[469, 10], [18, 440]]  0.969163
# 4        MLP  fold_4  0.962460  0.954148  [[465, 14], [21, 437]]  0.961496
# 5        MLP  fold_5  0.978501  0.971616   [[472, 7], [13, 445]]  0.978022
# 6        MLP  fold_6  0.960473  0.960613  [[460, 19], [18, 439]]  0.959563
# 7        MLP  fold_7  0.969126  0.973742  [[462, 17], [12, 445]]  0.968444
# 8        MLP  fold_8  0.964950  0.973742  [[458, 21], [12, 445]]  0.964247
# 9        MLP  fold_9  0.969918  0.962801  [[468, 11], [17, 440]]  0.969163
#
#    training_time  inference_time  error_rate  train_accuracy  test_accuracy  \
# 0      32.062275        0.004502    0.023479        0.986831       0.976521
# 1      32.303015        0.008844    0.026681        0.987899       0.973319
# 2      21.888020        0.000000    0.039488        0.987543       0.960512
# 3      26.969931        0.008083    0.029883        0.988255       0.970117
# 4      23.926166        0.000000    0.037353        0.987306       0.962647
# 5      25.021163        0.005626    0.021345        0.987187       0.978655
# 6      28.943169        0.007898    0.039530        0.987900       0.960470
# 7      31.666447        0.002891    0.030983        0.985884       0.969017
# 8      27.974724        0.008333    0.035256        0.985291       0.964744
# 9      21.546491        0.008264    0.029915        0.987663       0.970085
#
#    precision
# 0   0.984444
# 1   0.982183
# 2   0.966741
# 3   0.977778
# 4   0.968958
# 5   0.984513
# 6   0.958515
# 7   0.963203
# 8   0.954936
# 9   0.975610

# %%
cv = cross_validation(X_train_adasyn, y_train_adasyn, ensembles)
# Out:
# Model Heterogêneo
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5
# Fold: 6
# Fold: 7
# Fold: 8
# Fold: 9
#
#  Metrics:
#     model_name    fold      ACSA    recall                      CM  f1_score  \
# 0  Heterogêneo  fold_0  0.980732  0.978166   [[471, 8], [10, 448]]  0.980306
# 1  Heterogêneo  fold_1  0.975178  0.962882   [[473, 6], [17, 441]]  0.974586
# 2  Heterogêneo  fold_2  0.963456  0.951965  [[467, 12], [22, 436]]  0.962472
# 3  Heterogêneo  fold_3  0.973090  0.962882   [[471, 8], [17, 441]]  0.972437
# 4  Heterogêneo  fold_4  0.971003  0.962882  [[469, 10], [17, 441]]  0.970297
# 5  Heterogêneo  fold_5  0.978692  0.980349   [[468, 11], [9, 449]]  0.978214
# 6  Heterogêneo  fold_6  0.970069  0.969365  [[465, 14], [14, 443]]  0.969365
# 7  Heterogêneo  fold_7  0.971956  0.960613   [[471, 8], [18, 439]]  0.971239
# 8  Heterogêneo  fold_8  0.975389  0.973742  [[468, 11], [12, 445]]  0.974808
# 9  Heterogêneo  fold_9  0.971012  0.964989  [[468, 11], [16, 441]]  0.970297
#
#    training_time  inference_time  error_rate  train_accuracy  test_accuracy  \
# 0       3.231966        0.164047    0.019210        0.987187       0.980790
# 1       3.155030        0.166775    0.024546        0.986950       0.975454
# 2       3.149612        0.160595    0.036286        0.988018       0.963714
# 3       3.124726        0.164542    0.026681        0.988492       0.973319
# 4       3.226382        0.166740    0.028815        0.988611       0.971185
# 5       3.124672        0.153141    0.021345        0.987187       0.978655
# 6       3.136608        0.158354    0.029915        0.988493       0.970085
# 7       3.122453        0.166491    0.027778        0.988138       0.972222
# 8       3.099358        0.159665    0.024573        0.986595       0.975427
# 9       3.138912        0.164341    0.028846        0.988019       0.971154
#
#    precision
# 0   0.982456
# 1   0.986577
# 2   0.973214
# 3   0.982183
# 4   0.977827
# 5   0.976087
# 6   0.969365
# 7   0.982103
# 8   0.975877
# 9   0.975664
# Model ANNs
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# Fold: 5
# Fold: 6
# Fold: 7
# Fold: 8
# Fold: 9
#
#  Metrics:
#   model_name    fold      ACSA    recall                      CM  f1_score  \
# 0       ANNs  fold_0  0.976461  0.973799  [[469, 10], [12, 446]]  0.975930
# 1       ANNs  fold_1  0.973186  0.967249  [[469, 10], [15, 443]]  0.972558
# 2       ANNs  fold_2  0.962604  0.960699  [[462, 17], [18, 440]]  0.961749
# 3       ANNs  fold_3  0.974278  0.969432  [[469, 10], [14, 444]]  0.973684
# 4       ANNs  fold_4  0.967680  0.954148   [[470, 9], [21, 437]]  0.966814
# 5       ANNs  fold_5  0.976557  0.978166  [[467, 12], [10, 448]]  0.976035
# 6       ANNs  fold_6  0.962461  0.956236  [[464, 15], [20, 437]]  0.961496
# 7       ANNs  fold_7  0.973050  0.962801   [[471, 8], [17, 440]]  0.972376
# 8       ANNs  fold_8  0.970962  0.962801  [[469, 10], [17, 440]]  0.970232
# 9       ANNs  fold_9  0.972106  0.967177  [[468, 11], [15, 442]]  0.971429
#
#    training_time  inference_time  error_rate  train_accuracy  test_accuracy  \
# 0      80.737237        0.012562    0.023479        0.987424       0.976521
# 1      84.515298        0.014464    0.026681        0.988018       0.973319
# 2      73.146804        0.016878    0.037353        0.987899       0.962647
# 3      82.993108        0.017246    0.025614        0.988611       0.974386
# 4      84.540842        0.007555    0.032017        0.988373       0.967983
# 5      67.196651        0.008596    0.023479        0.986950       0.976521
# 6      68.169785        0.010172    0.037393        0.988019       0.962607
# 7      84.395249        0.015203    0.026709        0.987900       0.973291
# 8      84.428629        0.012395    0.028846        0.987426       0.971154
# 9      80.138379        0.013630    0.027778        0.988019       0.972222
#
#    precision
# 0   0.978070
# 1   0.977925
# 2   0.962801
# 3   0.977974
# 4   0.979821
# 5   0.973913
# 6   0.966814
# 7   0.982143
# 8   0.977778
# 9   0.975717
